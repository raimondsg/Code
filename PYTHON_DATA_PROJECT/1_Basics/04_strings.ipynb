# %%
"This is a string in double quotes"
# Out:
# 'This is a string in double quotes'

# %%
'This is a string in single quotes'
# Out:
# 'This is a string in single quotes'

# %%
skill = "Python"
skill.upper()
skill.lower()
# Out:
# 'python'

# %%
"Python".lower()
# Out:
# 'python'

# %%
str.lower("Python")
# Out:
# 'python'

# %%
skill.replace("P", "J")
# Out:
# 'Jython'

# %%
job_title = "Data Analyst"
job_title = job_title.replace("a", "o",2)

# %%
job_title.split(sep=" ", maxsplit=1)
# Out:
# ['Doto', 'Analyst']

# %% [markdown]
# #Dundr Methods

# %%
str.__add__("Data", "Analyst")
# Out:
# 'DataAnalyst'

# %%
"Data".__add__("Analyst")
# Out:
# 'DataAnalyst'

# %%
"Data" + "Analyst"
# Out:
# 'DataAnalyst'

# %%
" Data" + " Analyst" *10
# Out:
# ' Data Analyst Analyst Analyst Analyst Analyst Analyst Analyst Analyst Analyst Analyst'

# %%
len("Data Analyst")
# Out:
# 12
