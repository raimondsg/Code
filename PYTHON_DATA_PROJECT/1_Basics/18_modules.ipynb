# %%
import my_module
my_module.skill_list
# Out:
# ['Python', 'SQL', 'Excel']

# %%
my_module.skill("R")
# Out:
# 'R is my favorite skill'

# %%
from job_analyzer import calculate_salary

calculate_salary(1000000)
# Out:
# 1100000.0

# %%
from job_analyzer import *

calculate_salary(1000000)
calculate_bonus(1100000,1000000)
# Out:
# 0.1

# %%
 help(calculate_salary)
# Out:
# Help on function calculate_salary in module job_analyzer:
#
# calculate_salary(base_salary, bonus_rate=0.1)
#     Calclulate the total salary based on the base salary and bonus salary

# %%
salary_list = [98000, 101000, 102000, 99000, 97000]

# %%
from statistics import mean, mode, median

print(mean(salary_list))
print(mode(salary_list))
print(median(salary_list))
# Out:
# 99400
# 98000
# 99000
