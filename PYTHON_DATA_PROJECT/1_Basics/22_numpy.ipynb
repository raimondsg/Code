# %%
# create a list of 1,000,000 salaries ranging from 50,000 to 150,000
import random

salary_list = [random.randint(50000, 150000) for _ in range(1_000_000)]

# %%
import statistics
# Out:
# 419 ms ± 89.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
statistics.mean(salary_list)
# Out:
# 739 ms ± 209 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit
np.mean(salary_list)
# Out:
# 57.1 ms ± 13.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
my_array = np.array([1,2,3,4])

# %%
my_array.mean()
# Out:
# 2.5

# %%
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Data Engineer', 'Machine Learning Engineer', 'AI Engineer'])
base_salaries = np.array([50000, 60000, 70000, 80000, np.nan])
bonus_rates = np.array([0.05, 0.1, 0.08, 0.12, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([52500., 66000., 75600., 89600.,    nan])

# %%
np.nanmean(total_salaries)
# Out:
# 70925.0
