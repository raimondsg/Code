# %% [markdown]
# #Efficient extraction of UNIQUE VALUES

# %%
job_skills = {'python', 'SQL', 'statistics', 'tableau'}

# %%
job_skills
# Out:
# {'SQL', 'python', 'statistics', 'tableau'}

# %%
job_skills.add('R')
job_skills
# Out:
# {'R', 'SQL', 'python', 'statistics', 'tableau'}

# %%
job_skills.remove('SQL')
job_skills
# Out:
# {'R', 'python', 'statistics', 'tableau'}

# %%
skill_list = ['python', 'SQL', 'statistics', 'tableau','python', 'SQL', 'statistics', 'tableau']

# %%
set(skill_list)
# Out:
# {'SQL', 'python', 'statistics', 'tableau'}

# %%
list(set(skill_list))
# Out:
# ['statistics', 'tableau', 'python', 'SQL']
