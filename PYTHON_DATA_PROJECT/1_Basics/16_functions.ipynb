# %%
skill_list = ['Python', 'SQL', 'Excel']

# %%
type(skill_list)
# Out:
# list

# %%
len(skill_list)
# Out:
# 3

# %% [markdown]
# [python documentation](docs.python.org/3/libary/functions.html)

# %%
data_salaries = [95000, 100000, 85000, 97000, 140000]

# %%
min(data_salaries)
# Out:
# 85000

# %%
max(data_salaries)
# Out:
# 140000

# %%
sorted(data_salaries)
# Out:
# [85000, 95000, 97000, 100000, 140000]

# %% [markdown]
# User defined functions

# %%
def calculate_salary(base_salary, bonus_rate):

  total_salary = base_salary * (1+ bonus_rate)
  return total_salary

# %%
calculate_salary(150000,0.3)
# Out:
# 195000.0

# %%
#with optional
def calculate_salary(base_salary, bonus_rate=.1):

  total_salary = base_salary * (1+ bonus_rate)
  return total_salary

# %%
salary_1 = 100000
calculate_salary(salary_1)
# Out:
# 110000.00000000001
