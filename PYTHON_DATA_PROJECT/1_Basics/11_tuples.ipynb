# %% [markdown]
# #Tuples are for FIXED DATA (more applicable in software engineering)

# %%
lukes_skill = ('python', 'sql', 'statistics', 'tableau')

lukes_skill
# Out:
# ('python', 'sql', 'statistics', 'tableau')

# %%
lukes_skill[0]
# Out:
# 'python'

# %%
lukes_skill.append('r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-26909938fe5b> in <cell line: 1>()
# ----> 1 lukes_skill.append('r')
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
help(tuple)
# Out:
# Help on class tuple in module builtins:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Built-in subclasses:
#  |      asyncgen_hooks
#  |      UnraisableHookArgs
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
# ...

# %%
#since tuples are IMMUTABLE, you have to sorta create new tuple with new data (different ID)
print(lukes_skill)
new_skills = ('excel', 'power bi')
print(id(lukes_skill))

lukes_skill += new_skills
lukes_skill
id(lukes_skill)
# Out:
# ('python', 'sql', 'statistics', 'tableau')
# 134496713825376
# 134496094125504

# %%
range(5)
# Out:
# range(0, 5)

# %%
tuple(range(2,5))
# Out:
# (2, 3, 4)

# %%
tuple(range(0,101,17))
# Out:
# (0, 17, 34, 51, 68, 85)
