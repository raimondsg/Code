# %% [markdown]
# #Lists with words and stuff like csv files

# %%
job_skills = ["sql", "tableau", "excel"]

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
job_skills.append("python")
job_skills
# Out:
# ['sql', 'tableau', 'excel', 'python']

# %%
job_skills.remove("tableau")
job_skills
# Out:
# ['sql', 'excel', 'python']

# %%
job_skills[1]
# Out:
# 'excel'

# %%
job_skills.insert(2, "java")
job_skills
# Out:
# ['sql', 'excel', 'java', 'python']

# %%
job_skills.pop()
job_skills
# Out:
# ['sql', 'excel', 'java']

# %% [markdown]
# #Slicing

# %%
job_skills = ["sql", "tableau", "excel", "python", "java"]
job_skills[1:4]
# Out:
# ['tableau', 'excel', 'python']

# %%
job_skills[:]
# Out:
# ['sql', 'tableau', 'excel', 'python', 'java']

# %%
job_skills[::2]
# Out:
# ['sql', 'excel', 'java']

# %%
luke_skills = ["python", "sql", "tableau"]
kelly_skills = ["excel", "python", "java"]

all_skills = luke_skills + kelly_skills
all_skills
# Out:
# ['python', 'sql', 'tableau', 'excel', 'python', 'java']

# %%
all_skills[::2]
# Out:
# ['python', 'tableau', 'python']

# %%
all_skills[5:]
# Out:
# ['java']

# %%
all_skills[-1:]
# Out:
# ['java']

# %%
skill1, skill2, skill3 = luke_skills

# %%
skill2
# Out:
# 'sql'

# %%
skill_concerned, *skill_dontcare = job_skills

# %%
print(skill_concerned)
print(skill_dontcare)
# Out:
# sql
# ['tableau', 'excel', 'python', 'java']
