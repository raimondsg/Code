# %% [markdown]
# #Create a variable
#
# Total Salary = (Base Salary)*(1 + Bonus Rate)

# %%
base_salary = 100000
bonus_rate = 0.1

# %%
total_salary = base_salary * (1 + bonus_rate)

# %%
total_salary
# Out:
# 110000.00000000001

# %%
company_name = 'DataWiz Inc.'

# %%
company_name
# Out:
# 'DataWiz Inc.'
