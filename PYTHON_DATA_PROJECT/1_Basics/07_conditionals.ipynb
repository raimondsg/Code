# %%
job_skill = 'Python'
applicant_skill = 'Python'
if job_skill == applicant_skill:
    print('You are qualified')
else:
    print('You are not qualified')
# Out:
# You are qualified

# %%
job_skill = 'SQL'
applicant_skill = 'Python'
years_experience = 5

if applicant_skill == job_skill:
    print('You are qualified')
elif years_experience >=5:
  print('Enough Experience; No SQL')
# Out:
# Enough Experience; No SQL

# %%
job_skill = 'SQL'
applicant_skill = 'Python'
years_experience = 3

if applicant_skill == job_skill:
    print('You are qualified')
elif years_experience >=5:
  print('Enough Experience; No SQL')
elif applicant_skill == 'Python':
  print('Knows Python so should know SQL')
else:
  print('You are not qualified')
# Out:
# Knows Python so should know SQL

# %%
if job_skill == applicant_skill:
  pass

# %%
#just skil if doesn't work
