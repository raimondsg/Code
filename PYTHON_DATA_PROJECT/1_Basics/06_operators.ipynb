# %%
5/2
# Out:
# 2.5

# %%
5//2
# Out:
# 2

# %%
5 % 2
# Out:
# 1

# %%
min_salary = 20_000
max_salary = 50_000

# %%
avg_salary = (min_salary + max_salary) / 2
avg_salary
# Out:
# 35000.0

# %%
applicant_1 = "Luke"
applicant_2 = "Skywalker"

# %%
temp_var = applicant_1

# %%
applicant_1 = applicant_2
applicant_2 = temp_var

# %%
applicant_1, applicant_2
# Out:
# ('Skywalker', 'Luke')

# %%
applicant_1, applicant_2 = applicant_2, applicant_1

# %%
applicant_1, applicant_2
# Out:
# ('Luke', 'Skywalker')

# %%
x = 1
x += 1
x
# Out:
# 2

# %%
x*=2
x
# Out:
# 4

# %% [markdown]
# #Comparison operators

# %%
min_salary == max_salary
# Out:
# False

# %%
if (min_salary < max_salary):
  print("min_salary is less than max_salary")
# Out:
# min_salary is less than max_salary
