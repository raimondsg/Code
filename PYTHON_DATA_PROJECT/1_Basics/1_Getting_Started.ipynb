# %%
# This is a comment
print(2+2)
print(3 * 3)
# Out:
# 4
# 9

# %% [markdown]
# This is nomral text
#
# # Heading
#
# **bold**
#
# 1. one
# 2. two
# 3. three
#
# [Here is more info on Markdown] (https://www.youtube.com/watch?v=wUSDVGivd-8)

# %%
# !ls
# Out:
# sample_data

# %%
# %timeit [i**2 for i in range(1000)]
# Out:
# 308 µs ± 8.27 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
  L.append(n**2)
# Out:
# 336 µs ± 9.58 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
